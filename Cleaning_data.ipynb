# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML_PROJECT/assests/feature_selected_voice_data.csv')

# %%
df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'kurt', 'sp.ent',
#        'sfm', 'mode', 'meanfun', 'minfun', 'modindx', 'label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   kurt      3168 non-null   float64
#  7   sp.ent    3168 non-null   float64
#  8   sfm       3168 non-null   float64
#  9   mode      3168 non-null   float64
#  10  meanfun   3168 non-null   float64
#  11  minfun    3168 non-null   float64
#  12  modindx   3168 non-null   float64
#  13  label     3168 non-null   object
# dtypes: float64(13), object(1)
# memory usage: 346.6+ KB

# %% [markdown]
# ##### Number of Null values in every columns

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# meanfun     0
# minfun      0
# modindx     0
# label       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#            count       mean         std       min       25%       50%  \
# meanfreq  3168.0   0.180907    0.029918  0.039363  0.163662  0.184838
# sd        3168.0   0.057126    0.016652  0.018363  0.041954  0.059155
# median    3168.0   0.185621    0.036360  0.010975  0.169593  0.190032
# Q25       3168.0   0.140456    0.048680  0.000229  0.111087  0.140286
# Q75       3168.0   0.224765    0.023639  0.042946  0.208747  0.225684
# IQR       3168.0   0.084309    0.042783  0.014558  0.042560  0.094280
# kurt      3168.0  36.568461  134.928661  2.068455  5.669547  8.318463
# sp.ent    3168.0   0.895127    0.044980  0.738651  0.861811  0.901767
# sfm       3168.0   0.408216    0.177521  0.036876  0.258041  0.396335
# mode      3168.0   0.165282    0.077203  0.000000  0.118016  0.186599
# meanfun   3168.0   0.142807    0.032304  0.055565  0.116998  0.140519
# minfun    3168.0   0.036802    0.019220  0.009775  0.018223  0.046110
# modindx   3168.0   0.173752    0.119454  0.000000  0.099766  0.139357
#
#                 75%          max
# meanfreq   0.199146     0.251124
# sd         0.067020     0.115273
# median     0.210618     0.261224
# Q25        0.175939     0.247347
# Q75        0.243660     0.273469
# IQR        0.114175     0.252225
# kurt      13.648905  1309.612887
# sp.ent     0.928713     0.981997
# sfm        0.533676     0.842936
# mode       0.221104     0.280000
# meanfun    0.169581     0.237636
# minfun     0.047904     0.204082
# modindx    0.209183     0.932374

# %% [markdown]
# ##### Duplicates values in Data

# %% [markdown]
# Only two Duplicate Data in Datset
#
# Not much duplicates present, no need to remove

# %%
df[df.duplicated()]
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      kurt  \
# 298   0.213732  0.057705  0.242573  0.141701  0.257984  0.116283  7.890927
# 2403  0.212190  0.043190  0.215153  0.188957  0.245644  0.056687  6.109790
#
#         sp.ent       sfm      mode   meanfun    minfun   modindx   label
# 298   0.859712  0.084934  0.248978  0.133667  0.028319  0.229051    male
# 2403  0.877669  0.314398  0.188957  0.139942  0.047198  0.121344  female

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Normalize the Dataset

# %%
x = StandardScaler()

x.fit(df.drop('label', axis=1))

scaled_df = x.transform(df.drop('label', axis=1))

scaled_df = pd.DataFrame(scaled_df, columns=df.columns[:-1])

# %% [markdown]
# Shuffle the dataset randomly (because all males & female were grouped)

# %%
scaled_df['gender'] = df['label']

scaled_df = scaled_df.sample(frac=1)

scaled_df.index = np.arange(scaled_df.shape[0])

# %%
scaled_df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      kurt  \
# 0  0.602758  0.355976  1.055699 -0.142117  1.567427  1.027768 -0.210519
# 1  0.642158  0.219537  0.936464  1.053742  0.626879 -0.852602 -0.204561
# 2 -0.495719 -0.169618 -0.309233  0.445927 -1.448345 -1.307654 -0.139015
# 3 -0.708439  0.021716 -0.541947  0.177739 -1.431259 -0.993061 -0.154961
# 4  1.763427 -1.871090  1.387941  1.710837  0.914199 -1.441506 -0.130894
#
#      sp.ent       sfm      mode   meanfun    minfun   modindx  gender
# 0 -0.540272 -0.835728  1.318746 -0.357016  0.582726 -1.266497    male
# 1  0.214854  0.510834  0.914485  0.223601 -1.088261  0.743066  female
# 2 -0.257852  0.191444  0.056141  0.986513 -1.022684  0.238451  female
# 3  0.057054  0.131876 -2.141210  0.675466 -0.643929  2.324912  female
# 4 -2.543075 -1.691409  0.917164  1.851877  0.805841 -0.133960  female

# %%
scaled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3168 entries, 0 to 3167
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   kurt      3168 non-null   float64
#  7   sp.ent    3168 non-null   float64
#  8   sfm       3168 non-null   float64
#  9   mode      3168 non-null   float64
#  10  meanfun   3168 non-null   float64
#  11  minfun    3168 non-null   float64
#  12  modindx   3168 non-null   float64
#  13  gender    3168 non-null   object
# dtypes: float64(13), object(1)
# memory usage: 371.2+ KB

# %%
scaled_df.to_csv('/content/drive/MyDrive/ML_PROJECT/assests/scaled_voice_data.csv', index=False)
